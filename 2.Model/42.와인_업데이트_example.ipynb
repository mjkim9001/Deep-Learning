# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# seed값 설정
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('../dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)
dataset = df.values
X = dataset[:, 0:12]
Y = dataset[:, 12]

# %%
# 모델 설정
model = Sequential([
    Dense(30, input_dim = 12, activation='relu'),
    Dense(12, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                390
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics =['accuracy'])

# %%
# 모델 저장 폴더 설정
import os
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# 모델 저장 조건 설정
from tensorflow.keras.callbacks import ModelCheckpoint
modelpath = MODEL_DIR + 'wine{epoch:03d}-{val_loss:.4f}.hdf5'

checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1)

# %%
# 모델 실행 및 저장
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 00001: saving model to ./model/wine001-0.5909.hdf5
#
# Epoch 00002: saving model to ./model/wine002-0.3186.hdf5
#
# Epoch 00003: saving model to ./model/wine003-0.2717.hdf5
#
# Epoch 00004: saving model to ./model/wine004-0.2569.hdf5
#
# Epoch 00005: saving model to ./model/wine005-0.2485.hdf5
#
# Epoch 00006: saving model to ./model/wine006-0.2375.hdf5
#
# Epoch 00007: saving model to ./model/wine007-0.2290.hdf5
#
# Epoch 00008: saving model to ./model/wine008-0.2197.hdf5
#
# Epoch 00009: saving model to ./model/wine009-0.2134.hdf5
#
# Epoch 00010: saving model to ./model/wine010-0.2120.hdf5
#
# Epoch 00011: saving model to ./model/wine011-0.2041.hdf5
#
# Epoch 00012: saving model to ./model/wine012-0.1998.hdf5
#
# Epoch 00013: saving model to ./model/wine013-0.1967.hdf5
#
# Epoch 00014: saving model to ./model/wine014-0.1976.hdf5
#
# Epoch 00015: saving model to ./model/wine015-0.1896.hdf5
#
# Epoch 00016: saving model to ./model/wine016-0.1922.hdf5
#
# Epoch 00017: saving model to ./model/wine017-0.1868.hdf5
#
# Epoch 00018: saving model to ./model/wine018-0.1807.hdf5
#
# Epoch 00019: saving model to ./model/wine019-0.1788.hdf5
#
# Epoch 00020: saving model to ./model/wine020-0.1780.hdf5
#
# Epoch 00021: saving model to ./model/wine021-0.1749.hdf5
#
# Epoch 00022: saving model to ./model/wine022-0.1792.hdf5
#
# Epoch 00023: saving model to ./model/wine023-0.1681.hdf5
#
# Epoch 00024: saving model to ./model/wine024-0.1725.hdf5
#
# Epoch 00025: saving model to ./model/wine025-0.1636.hdf5
#
# Epoch 00026: saving model to ./model/wine026-0.1610.hdf5
#
# Epoch 00027: saving model to ./model/wine027-0.1586.hdf5
#
# Epoch 00028: saving model to ./model/wine028-0.1591.hdf5
#
# Epoch 00029: saving model to ./model/wine029-0.1609.hdf5
#
# Epoch 00030: saving model to ./model/wine030-0.1547.hdf5
#
# Epoch 00031: saving model to ./model/wine031-0.1503.hdf5
#
# Epoch 00032: saving model to ./model/wine032-0.1587.hdf5
#
# Epoch 00033: saving model to ./model/wine033-0.1444.hdf5
#
# Epoch 00034: saving model to ./model/wine034-0.1414.hdf5
#
# Epoch 00035: saving model to ./model/wine035-0.1398.hdf5
#
# Epoch 00036: saving model to ./model/wine036-0.1466.hdf5
#
# Epoch 00037: saving model to ./model/wine037-0.1399.hdf5
#
# Epoch 00038: saving model to ./model/wine038-0.1345.hdf5
#
# Epoch 00039: saving model to ./model/wine039-0.1342.hdf5
#
# Epoch 00040: saving model to ./model/wine040-0.1291.hdf5
#
# Epoch 00041: saving model to ./model/wine041-0.1283.hdf5
#
# Epoch 00042: saving model to ./model/wine042-0.1318.hdf5
#
# Epoch 00043: saving model to ./model/wine043-0.1228.hdf5
#
# Epoch 00044: saving model to ./model/wine044-0.1216.hdf5
#
# Epoch 00045: saving model to ./model/wine045-0.1223.hdf5
#
# Epoch 00046: saving model to ./model/wine046-0.1188.hdf5
#
# Epoch 00047: saving model to ./model/wine047-0.1189.hdf5
#
# Epoch 00048: saving model to ./model/wine048-0.1161.hdf5
#
# Epoch 00049: saving model to ./model/wine049-0.1127.hdf5
#
# Epoch 00050: saving model to ./model/wine050-0.1128.hdf5
#
# Epoch 00051: saving model to ./model/wine051-0.1139.hdf5
#
# Epoch 00052: saving model to ./model/wine052-0.1083.hdf5
#
# Epoch 00053: saving model to ./model/wine053-0.1107.hdf5
#
# Epoch 00054: saving model to ./model/wine054-0.1051.hdf5
#
# Epoch 00055: saving model to ./model/wine055-0.1040.hdf5
#
# Epoch 00056: saving model to ./model/wine056-0.1021.hdf5
#
# Epoch 00057: saving model to ./model/wine057-0.1011.hdf5
#
# Epoch 00058: saving model to ./model/wine058-0.0999.hdf5
#
# Epoch 00059: saving model to ./model/wine059-0.0988.hdf5
#
# Epoch 00060: saving model to ./model/wine060-0.0985.hdf5
#
# Epoch 00061: saving model to ./model/wine061-0.0981.hdf5
#
# Epoch 00062: saving model to ./model/wine062-0.1074.hdf5
#
# Epoch 00063: saving model to ./model/wine063-0.0963.hdf5
#
# Epoch 00064: saving model to ./model/wine064-0.1040.hdf5
#
# Epoch 00065: saving model to ./model/wine065-0.0922.hdf5
#
# Epoch 00066: saving model to ./model/wine066-0.0987.hdf5
#
# Epoch 00067: saving model to ./model/wine067-0.0930.hdf5
#
# Epoch 00068: saving model to ./model/wine068-0.0936.hdf5
#
# Epoch 00069: saving model to ./model/wine069-0.0890.hdf5
#
# Epoch 00070: saving model to ./model/wine070-0.1088.hdf5
#
# Epoch 00071: saving model to ./model/wine071-0.0878.hdf5
#
# Epoch 00072: saving model to ./model/wine072-0.0862.hdf5
#
# Epoch 00073: saving model to ./model/wine073-0.1160.hdf5
#
# Epoch 00074: saving model to ./model/wine074-0.0966.hdf5
#
# Epoch 00075: saving model to ./model/wine075-0.0871.hdf5
#
# Epoch 00076: saving model to ./model/wine076-0.0841.hdf5
#
# Epoch 00077: saving model to ./model/wine077-0.0987.hdf5
#
# Epoch 00078: saving model to ./model/wine078-0.0837.hdf5
#
# Epoch 00079: saving model to ./model/wine079-0.0903.hdf5
#
# Epoch 00080: saving model to ./model/wine080-0.0960.hdf5
#
# Epoch 00081: saving model to ./model/wine081-0.0810.hdf5
#
# Epoch 00082: saving model to ./model/wine082-0.0808.hdf5
#
# Epoch 00083: saving model to ./model/wine083-0.0959.hdf5
#
# Epoch 00084: saving model to ./model/wine084-0.0814.hdf5
#
# Epoch 00085: saving model to ./model/wine085-0.0809.hdf5
#
# Epoch 00086: saving model to ./model/wine086-0.0830.hdf5
#
# Epoch 00087: saving model to ./model/wine087-0.0780.hdf5
#
# Epoch 00088: saving model to ./model/wine088-0.0796.hdf5
#
# Epoch 00089: saving model to ./model/wine089-0.0912.hdf5
#
# Epoch 00090: saving model to ./model/wine090-0.0908.hdf5
#
# Epoch 00091: saving model to ./model/wine091-0.0794.hdf5
#
# Epoch 00092: saving model to ./model/wine092-0.0879.hdf5
#
# Epoch 00093: saving model to ./model/wine093-0.0760.hdf5
#
# Epoch 00094: saving model to ./model/wine094-0.0761.hdf5
#
# Epoch 00095: saving model to ./model/wine095-0.0754.hdf5
#
# Epoch 00096: saving model to ./model/wine096-0.0812.hdf5
#
# Epoch 00097: saving model to ./model/wine097-0.0787.hdf5
#
# Epoch 00098: saving model to ./model/wine098-0.0775.hdf5
#
# Epoch 00099: saving model to ./model/wine099-0.0835.hdf5
#
# Epoch 00100: saving model to ./model/wine100-0.0807.hdf5
#
# Epoch 00101: saving model to ./model/wine101-0.0738.hdf5
#
# Epoch 00102: saving model to ./model/wine102-0.0745.hdf5
#
# Epoch 00103: saving model to ./model/wine103-0.0745.hdf5
#
# Epoch 00104: saving model to ./model/wine104-0.0833.hdf5
#
# Epoch 00105: saving model to ./model/wine105-0.0738.hdf5
#
# Epoch 00106: saving model to ./model/wine106-0.0768.hdf5
#
# Epoch 00107: saving model to ./model/wine107-0.0761.hdf5
#
# Epoch 00108: saving model to ./model/wine108-0.0724.hdf5
#
# Epoch 00109: saving model to ./model/wine109-0.0744.hdf5
#
# Epoch 00110: saving model to ./model/wine110-0.0722.hdf5
#
# Epoch 00111: saving model to ./model/wine111-0.0902.hdf5
#
# Epoch 00112: saving model to ./model/wine112-0.0958.hdf5
#
# Epoch 00113: saving model to ./model/wine113-0.0809.hdf5
#
# Epoch 00114: saving model to ./model/wine114-0.0719.hdf5
#
# Epoch 00115: saving model to ./model/wine115-0.0757.hdf5
#
# Epoch 00116: saving model to ./model/wine116-0.0763.hdf5
#
# Epoch 00117: saving model to ./model/wine117-0.0774.hdf5
#
# Epoch 00118: saving model to ./model/wine118-0.0704.hdf5
#
# Epoch 00119: saving model to ./model/wine119-0.0781.hdf5
#
# Epoch 00120: saving model to ./model/wine120-0.0710.hdf5
#
# Epoch 00121: saving model to ./model/wine121-0.0695.hdf5
#
# Epoch 00122: saving model to ./model/wine122-0.0693.hdf5
#
# Epoch 00123: saving model to ./model/wine123-0.0859.hdf5
#
# Epoch 00124: saving model to ./model/wine124-0.0729.hdf5
#
# Epoch 00125: saving model to ./model/wine125-0.0821.hdf5
#
# Epoch 00126: saving model to ./model/wine126-0.0778.hdf5
#
# Epoch 00127: saving model to ./model/wine127-0.0756.hdf5
#
# Epoch 00128: saving model to ./model/wine128-0.0701.hdf5
#
# Epoch 00129: saving model to ./model/wine129-0.0723.hdf5
#
# Epoch 00130: saving model to ./model/wine130-0.0763.hdf5
#
# Epoch 00131: saving model to ./model/wine131-0.0685.hdf5
#
# Epoch 00132: saving model to ./model/wine132-0.0777.hdf5
#
# Epoch 00133: saving model to ./model/wine133-0.0698.hdf5
#
# Epoch 00134: saving model to ./model/wine134-0.0837.hdf5
#
# Epoch 00135: saving model to ./model/wine135-0.0775.hdf5
#
# Epoch 00136: saving model to ./model/wine136-0.0812.hdf5
#
# Epoch 00137: saving model to ./model/wine137-0.0713.hdf5
#
# Epoch 00138: saving model to ./model/wine138-0.0683.hdf5
#
# Epoch 00139: saving model to ./model/wine139-0.0722.hdf5
#
# Epoch 00140: saving model to ./model/wine140-0.0679.hdf5
#
# Epoch 00141: saving model to ./model/wine141-0.0685.hdf5
#
# Epoch 00142: saving model to ./model/wine142-0.0701.hdf5
#
# Epoch 00143: saving model to ./model/wine143-0.0775.hdf5
#
# Epoch 00144: saving model to ./model/wine144-0.0677.hdf5
#
# Epoch 00145: saving model to ./model/wine145-0.0768.hdf5
#
# Epoch 00146: saving model to ./model/wine146-0.0802.hdf5
#
# Epoch 00147: saving model to ./model/wine147-0.0688.hdf5
# Epoch 00148: saving model to ./model/wine148-0.0673.hdf5
#
# Epoch 00149: saving model to ./model/wine149-0.0724.hdf5
#
# Epoch 00150: saving model to ./model/wine150-0.0676.hdf5
#
# Epoch 00151: saving model to ./model/wine151-0.0679.hdf5
#
# Epoch 00152: saving model to ./model/wine152-0.0681.hdf5
#
# Epoch 00153: saving model to ./model/wine153-0.0704.hdf5
#
# Epoch 00154: saving model to ./model/wine154-0.0723.hdf5
#
# Epoch 00155: saving model to ./model/wine155-0.0756.hdf5
#
# Epoch 00156: saving model to ./model/wine156-0.0703.hdf5
#
# Epoch 00157: saving model to ./model/wine157-0.0673.hdf5
#
# Epoch 00158: saving model to ./model/wine158-0.0792.hdf5
#
# Epoch 00159: saving model to ./model/wine159-0.0672.hdf5
#
# Epoch 00160: saving model to ./model/wine160-0.0780.hdf5
#
# Epoch 00161: saving model to ./model/wine161-0.0744.hdf5
#
# Epoch 00162: saving model to ./model/wine162-0.0696.hdf5
#
# Epoch 00163: saving model to ./model/wine163-0.0830.hdf5
#
# Epoch 00164: saving model to ./model/wine164-0.0706.hdf5
#
# Epoch 00165: saving model to ./model/wine165-0.0715.hdf5
#
# Epoch 00166: saving model to ./model/wine166-0.0684.hdf5
#
# Epoch 00167: saving model to ./model/wine167-0.0665.hdf5
#
# Epoch 00168: saving model to ./model/wine168-0.0712.hdf5
#
# Epoch 00169: saving model to ./model/wine169-0.0899.hdf5
#
# Epoch 00170: saving model to ./model/wine170-0.0678.hdf5
#
# Epoch 00171: saving model to ./model/wine171-0.0698.hdf5
#
# Epoch 00172: saving model to ./model/wine172-0.0702.hdf5
#
# Epoch 00173: saving model to ./model/wine173-0.0750.hdf5
#
# Epoch 00174: saving model to ./model/wine174-0.0674.hdf5
#
# Epoch 00175: saving model to ./model/wine175-0.0875.hdf5
#
# Epoch 00176: saving model to ./model/wine176-0.0687.hdf5
#
# Epoch 00177: saving model to ./model/wine177-0.0689.hdf5
#
# Epoch 00178: saving model to ./model/wine178-0.0707.hdf5
#
# Epoch 00179: saving model to ./model/wine179-0.0671.hdf5
#
# Epoch 00180: saving model to ./model/wine180-0.0690.hdf5
#
# Epoch 00181: saving model to ./model/wine181-0.0733.hdf5
#
# Epoch 00182: saving model to ./model/wine182-0.0850.hdf5
#
# Epoch 00183: saving model to ./model/wine183-0.0701.hdf5
#
# Epoch 00184: saving model to ./model/wine184-0.0743.hdf5
#
# Epoch 00185: saving model to ./model/wine185-0.0675.hdf5
#
# Epoch 00186: saving model to ./model/wine186-0.0766.hdf5
#
# Epoch 00187: saving model to ./model/wine187-0.0709.hdf5
#
# Epoch 00188: saving model to ./model/wine188-0.0814.hdf5
#
# Epoch 00189: saving model to ./model/wine189-0.0695.hdf5
#
# Epoch 00190: saving model to ./model/wine190-0.0690.hdf5
#
# Epoch 00191: saving model to ./model/wine191-0.0673.hdf5
#
# Epoch 00192: saving model to ./model/wine192-0.0681.hdf5
#
# Epoch 00193: saving model to ./model/wine193-0.0811.hdf5
#
# Epoch 00194: saving model to ./model/wine194-0.0691.hdf5
#
# Epoch 00195: saving model to ./model/wine195-0.0668.hdf5
#
# Epoch 00196: saving model to ./model/wine196-0.0676.hdf5
#
# Epoch 00197: saving model to ./model/wine197-0.0678.hdf5
#
# Epoch 00198: saving model to ./model/wine198-0.0705.hdf5
#
# Epoch 00199: saving model to ./model/wine199-0.0667.hdf5
#
# Epoch 00200: saving model to ./model/wine200-0.0794.hdf5
